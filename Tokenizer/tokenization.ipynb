# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
text = "ꙮ 𓃠 ⚗️ ҵ ⑇ ٩(◕‿◕)۶ ≋ ᚛ᚒᚐᚔᚋ᚜ ℵ"

[ord(x) for x in text]
# Out:
# [42606,
#  32,
#  78048,
#  32,
#  9879,
#  65039,
#  32,
#  1205,
#  32,
#  9287,
#  32,
#  1641,
#  40,
#  9685,
#  8255,
#  9685,
#  41,
#  1782,
#  32,
#  8779,
#  32,
#  5787,
#  5778,
#  5776,
#  5780,
#  5771,
#  5788,
#  32,
#  8501]

# %%
list(text.encode("utf-8"))
# Out:
# [234,
#  153,
#  174,
#  32,
#  240,
#  147,
#  131,
#  160,
#  32,
#  226,
#  154,
#  151,
#  239,
#  184,
#  143,
#  32,
#  210,
#  181,
#  32,
#  226,
#  145,
#  135,
#  32,
#  217,
#  169,
#  40,
#  226,
#  151,
#  149,
#  226,
#  128,
#  191,
#  226,
#  151,
#  149,
#  41,
#  219,
#  182,
#  32,
#  226,
#  137,
#  139,
#  32,
#  225,
#  154,
#  155,
#  225,
#  154,
#  146,
#  225,
#  154,
#  144,
#  225,
#  154,
#  148,
#  225,
#  154,
#  139,
#  225,
#  154,
#  156,
#  32,
#  226,
#  132,
#  181]
